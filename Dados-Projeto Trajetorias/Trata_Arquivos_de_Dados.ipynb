# %%
#!pip install openpyxl

# %%
import pandas as pd
import openpyxl

# %% [markdown]
# Selecionando os dados de malária:

# %%
epidem_indic = pd.read_excel('TRAJETORIAS_DATASET_Epidemiological_dimension_indicators.xlsx')

# Define os valores desejados
malaria = ['Falciparum', 'Vivax', 'Vivax+Falciparum']

# Filtra as linhas com os valores desejados na coluna 'disease'
malaria_df = epidem_indic[epidem_indic['disease'].isin(malaria)]

# Exibe as linhas filtradas
malaria_df = malaria_df.reset_index()
malaria_df = malaria_df.drop(['index'], axis=1)
malaria_df
# Out:
#       state_abbrev        state                      municipality  geocode  \
# 0               RO     Rondônia             Alta Floresta D'Oeste  1100015
# 1               RO     Rondônia           Alto Alegre dos Parecis  1100379
# 2               RO     Rondônia                      Alto Paraíso  1100403
# 3               RO     Rondônia                  Alvorada D'Oeste  1100346
# 4               RO     Rondônia                         Ariquemes  1100023
# ...            ...          ...                               ...      ...
# 13891           MT  Mato Grosso              Vale de São Domingos  5108352
# 13892           MT  Mato Grosso                     Várzea Grande  5108402
# 13893           MT  Mato Grosso                              Vera  5108501
# 13894           MT  Mato Grosso  Vila Bela da Santíssima Trindade  5105507
# 13895           MT  Mato Grosso                         Vila Rica  5108600
#
#           period   zone           disease  cases           inc
# 0      2004-2008  rural        Falciparum    121  1.952715e+14
# 1      2004-2008  rural        Falciparum     19  3.440703e+14
# 2      2004-2008  rural        Falciparum   5209  1.210386e+14
# 3      2004-2008  rural        Falciparum    159  3.415654e+13
# 4      2004-2008  rural        Falciparum   3106  4.669549e+14
# ...          ...    ...               ...    ...           ...
# 13891  2015-2019  total  Vivax+Falciparum      0  0.000000e+00
# 13892  2015-2019  total  Vivax+Falciparum      0  0.000000e+00
# 13893  2015-2019  total  Vivax+Falciparum      0  0.000000e+00
# 13894  2015-2019  total  Vivax+Falciparum      0  0.000000e+00
# 13895  2015-2019  total  Vivax+Falciparum      0  0.000000e+00
#
# [13896 rows x 9 columns]

# %%
malaria_df.to_excel('malaria_dataset.xlsx', index=False)

# %%
# Define os valores desejados
vivax = ['Vivax']

# Filtra as linhas com os valores desejados na coluna 'disease'
vivax_df = epidem_indic[epidem_indic['disease'].isin(vivax)]

# Exibe as linhas filtradas
vivax_df = vivax_df.reset_index()
vivax_df = vivax_df.drop(['index'], axis=1)
vivax_df
# Out:
#      state_abbrev        state                      municipality  geocode  \
# 0              RO     Rondônia             Alta Floresta D'Oeste  1100015
# 1              RO     Rondônia           Alto Alegre dos Parecis  1100379
# 2              RO     Rondônia                      Alto Paraíso  1100403
# 3              RO     Rondônia                  Alvorada D'Oeste  1100346
# 4              RO     Rondônia                         Ariquemes  1100023
# ...           ...          ...                               ...      ...
# 4627           MT  Mato Grosso              Vale de São Domingos  5108352
# 4628           MT  Mato Grosso                     Várzea Grande  5108402
# 4629           MT  Mato Grosso                              Vera  5108501
# 4630           MT  Mato Grosso  Vila Bela da Santíssima Trindade  5105507
# 4631           MT  Mato Grosso                         Vila Rica  5108600
#
#          period   zone disease  cases           inc
# 0     2004-2008  rural   Vivax    852  1.374969e+14
# 1     2004-2008  rural   Vivax    141  2.553363e+14
# 2     2004-2008  rural   Vivax  10721  2.491179e+12
# 3     2004-2008  rural   Vivax    975  2.094505e+14
# 4     2004-2008  rural   Vivax   8573  1.288862e+14
# ...         ...    ...     ...    ...           ...
# 4627  2015-2019  total   Vivax      0  0.000000e+00
# 4628  2015-2019  total   Vivax      0  0.000000e+00
# 4629  2015-2019  total   Vivax      0  0.000000e+00
# 4630  2015-2019  total   Vivax      0  0.000000e+00
# 4631  2015-2019  total   Vivax      0  0.000000e+00
#
# [4632 rows x 9 columns]

# %% [markdown]
# Buscando o estado com maior número de casos totais:

# %%
periodos_desejados = ['2004-2008', '2015-2019']
filtros = (epidem_indic['disease'].isin(malaria)) & (epidem_indic['period'].isin(periodos_desejados))
dados_filtrados = epidem_indic[filtros]

# Agrupa os dados por estado e soma os casos
soma_casos_por_estado = dados_filtrados.groupby('state')['cases'].sum()

# Ordena os estados em ordem decrescente de casos
soma_casos_por_estado = soma_casos_por_estado.sort_values(ascending=False)

# Obtém o estado com o maior número de casos
estado_maior_casos = soma_casos_por_estado.index[0]

#############################

# Agrupa os dados por estado e período

soma_casos_por_estado_periodo = dados_filtrados.groupby(['state', 'period'])['cases'].sum()

soma_casos_por_estado_periodo = soma_casos_por_estado_periodo.sort_values(ascending=False)

estado_periodo_maior_casos = soma_casos_por_estado_periodo.index[0]


# Exibe o estado com o maior índice de casos
print(soma_casos_por_estado)
print(' ')
print("Estado com maior índice de casos:", estado_maior_casos)
# Out:
# state
# Amazonas       2942448
# Pará           1531723
# Rondônia       1285857
# Acre            935609
# Roraima         420351
# Amapá           419318
# Maranhão        127282
# Mato Grosso      82837
# Tocantins         5494
# Name: cases, dtype: int64
#
# Estado com maior índice de casos: Amazonas

# %% [markdown]
# Buscando o estado com maior número de casos por período:

# %%
# Exibe o estado com o maior índice de casos
print(soma_casos_por_estado_periodo)
print(' ')
print("Estado com maior índice de casos:", estado_periodo_maior_casos)
# Out:
# state        period
# Amazonas     2004-2008    2149875
# Rondônia     2004-2008    1184044
# Pará         2004-2008    1169876
# Amazonas     2015-2019     792573
# Acre         2004-2008     621070
# Pará         2015-2019     361847
# Acre         2015-2019     314539
# Amapá        2004-2008     266271
# Roraima      2004-2008     243696
#              2015-2019     176655
# Amapá        2015-2019     153047
# Maranhão     2004-2008     117171
# Rondônia     2015-2019     101813
# Mato Grosso  2004-2008      71132
#              2015-2019      11705
# Maranhão     2015-2019      10111
# Tocantins    2004-2008       5141
#              2015-2019        353
# Name: cases, dtype: int64
#
# Estado com maior índice de casos: ('Amazonas', '2004-2008')

# %%
# Filtra os dados para o período de 2004-2008
dados_2004_2008 = dados_filtrados[dados_filtrados['period'] == '2004-2008']

# Agrupa os dados por estado e soma os casos para o período
soma_casos_2004_2008 = dados_2004_2008.groupby('state')['cases'].sum()

# Ordena os estados em ordem decrescente de casos para o período
soma_casos_2004_2008 = soma_casos_2004_2008.sort_values(ascending=False)

# Obtém o estado com o maior número de casos para o período
estado_maior_casos_2004_2008 = soma_casos_2004_2008.index[0]

###############

dados_2015_2019 = dados_filtrados[dados_filtrados['period'] == '2015-2019']

soma_casos_2015_2019 = dados_2015_2019.groupby('state')['cases'].sum()

soma_casos_2015_2019 = soma_casos_2015_2019.sort_values(ascending=False)

estado_maior_casos_2015_2019 = soma_casos_2015_2019.index[0]

# %%
# Exibe os estados com o maior índice de casos para cada período
print("Período de 2004-2008:")
print(soma_casos_2004_2008)
print("Estado com maior índice de casos no período de 2004-2008:", estado_maior_casos_2004_2008)

print(' ')

print("Período de 2015-2019:")
print(soma_casos_2015_2019)
print("Estado com maior índice de casos no período de 2015-2019:", estado_maior_casos_2015_2019)
# Out:
# Período de 2004-2008:
# state
# Amazonas       2149875
# Rondônia       1184044
# Pará           1169876
# Acre            621070
# Amapá           266271
# Roraima         243696
# Maranhão        117171
# Mato Grosso      71132
# Tocantins         5141
# Name: cases, dtype: int64
# Estado com maior índice de casos no período de 2004-2008: Amazonas
#
# Período de 2015-2019:
# state
# Amazonas       792573
# Pará           361847
# Acre           314539
# Roraima        176655
# Amapá          153047
# Rondônia       101813
# Mato Grosso     11705
# Maranhão        10111
# Tocantins         353
# Name: cases, dtype: int64
# Estado com maior índice de casos no período de 2015-2019: Amazonas

# %% [markdown]
# Buscando qual tipo de protozoário $Plasmodium$ causou mais infecções:

# %%
periodos_desejados = ['2004-2008', '2015-2019']
filtros = (epidem_indic['disease'].isin(malaria)) & (epidem_indic['period'].isin(periodos_desejados))
dados_filtrados = epidem_indic[filtros]

# Agrupa os dados por estado e soma os casos
soma_casos_por_especie = dados_filtrados.groupby('disease')['cases'].sum()

# Ordena os estados em ordem decrescente de casos
soma_casos_por_especie = soma_casos_por_especie.sort_values(ascending=False)

# Obtém o estado com o maior número de casos
especie_maior_casos = soma_casos_por_especie.index[0]

#############################

# Agrupa os dados por estado e período

soma_casos_por_especie_periodo = dados_filtrados.groupby(['disease', 'period'])['cases'].sum()

soma_casos_por_especie_periodo = soma_casos_por_especie_periodo.sort_values(ascending=False)

especie_periodo_maior_casos = soma_casos_por_especie_periodo.index[0]


# Exibe o estado com o maior índice de casos
print(soma_casos_por_especie)
print(' ')
print("Espécie com maior índice de casos:", especie_maior_casos)
# Out:
# disease
# Vivax               6175008
# Falciparum          1522261
# Vivax+Falciparum      53776
# Name: cases, dtype: int64
#
# Espécie com maior índice de casos: Vivax

# %% [markdown]
# Buscando qual tipo de protozoário $Plasmodium$ causou mais infecções por período:

# %%
# Filtra os dados para o período de 2004-2008
dados_2004_2008 = dados_filtrados[dados_filtrados['period'] == '2004-2008']

# Agrupa os dados por estado e soma os casos para o período
soma_casos_2004_2008 = dados_2004_2008.groupby('disease')['cases'].sum()

# Ordena os estados em ordem decrescente de casos para o período
soma_casos_2004_2008 = soma_casos_2004_2008.sort_values(ascending=False)

# Obtém o estado com o maior número de casos para o período
especie_maior_casos_2004_2008 = soma_casos_2004_2008.index[0]

###############

dados_2015_2019 = dados_filtrados[dados_filtrados['period'] == '2015-2019']

soma_casos_2015_2019 = dados_2015_2019.groupby('disease')['cases'].sum()

soma_casos_2015_2019 = soma_casos_2015_2019.sort_values(ascending=False)

especie_maior_casos_2015_2019 = soma_casos_2015_2019.index[0]

# %%
# Exibe as cidades com o maior índice de casos para cada período
print("Período de 2004-2008:")
print(soma_casos_2004_2008)
print("Espécie com maior índice de casos no período de 2004-2008:", especie_maior_casos_2004_2008)

print(' ')

print("Período de 2015-2019:")
print(soma_casos_2015_2019)
print("Espécie com maior índice de casos no período de 2015-2019:", especie_maior_casos_2015_2019)
# Out:
# Período de 2004-2008:
# disease
# Vivax               4429775
# Falciparum          1350721
# Vivax+Falciparum      47780
# Name: cases, dtype: int64
# Espécie com maior índice de casos no período de 2004-2008: Vivax
#
# Período de 2015-2019:
# disease
# Vivax               1745233
# Falciparum           171540
# Vivax+Falciparum       5996
# Name: cases, dtype: int64
# Espécie com maior índice de casos no período de 2015-2019: Vivax

# %% [markdown]
# Filtrando dados do estado do Amazonas:

# %%
# Define os valores desejados
amazonas = ['Amazonas']

# Filtra as linhas com os valores desejados na coluna 'state'
amazonas_df = epidem_indic[epidem_indic['state'].isin(amazonas)]

# Exibe as linhas filtradas
amazonas_df = amazonas_df.reset_index()
amazonas_df = amazonas_df.drop(['index'], axis=1)
amazonas_df
# Out:
#      state_abbrev     state municipality  geocode     period   zone  \
# 0              AM  Amazonas     Alvarães  1300029  2004-2008  rural
# 1              AM  Amazonas      Amaturá  1300060  2004-2008  rural
# 2              AM  Amazonas        Anamã  1300086  2004-2008  rural
# 3              AM  Amazonas        Anori  1300102  2004-2008  rural
# 4              AM  Amazonas         Apuí  1300144  2004-2008  rural
# ...           ...       ...          ...      ...        ...    ...
# 2599           AM  Amazonas         Tefé  1304203  2015-2019  total
# 2600           AM  Amazonas    Tonantins  1304237  2015-2019  total
# 2601           AM  Amazonas       Uarini  1304260  2015-2019  total
# 2602           AM  Amazonas      Urucará  1304302  2015-2019  total
# 2603           AM  Amazonas  Urucurituba  1304401  2015-2019  total
#
#                disease  cases           inc
# 0               chagas      0  0.000000e+00
# 1               chagas      0  0.000000e+00
# 2               chagas      1  4.867059e+14
# 3               chagas      0  0.000000e+00
# 4               chagas      0  0.000000e+00
# ...                ...    ...           ...
# 2599  Vivax+Falciparum     13  4.192128e+14
# 2600  Vivax+Falciparum      2  2.129699e+14
# 2601  Vivax+Falciparum      0  0.000000e+00
# 2602  Vivax+Falciparum      0  0.000000e+00
# 2603  Vivax+Falciparum      0  0.000000e+00
#
# [2604 rows x 9 columns]

# %% [markdown]
# Filtrando dados de malária no estado do Amazonas:

# %%
# Combina os DataFrames malaria_df e amazonas_df com base nas colunas desejadas
combined_df = amazonas_df.copy()

# Define os valores desejados de doenças
doencas_desejadas = ['Vivax', 'Falciparum', 'Vivax+Falciparum']

# Filtra as linhas com os valores desejados na coluna 'disease' no DataFrame amazonas_df
combined_df = combined_df[combined_df['disease'].isin(doencas_desejadas)]

# Exibe o DataFrame filtrado para o Amazonas
combined_df = combined_df.reset_index(drop=True)
combined_df
# Out:
#      state_abbrev     state municipality  geocode     period   zone  \
# 0              AM  Amazonas     Alvarães  1300029  2004-2008  rural
# 1              AM  Amazonas      Amaturá  1300060  2004-2008  rural
# 2              AM  Amazonas        Anamã  1300086  2004-2008  rural
# 3              AM  Amazonas        Anori  1300102  2004-2008  rural
# 4              AM  Amazonas         Apuí  1300144  2004-2008  rural
# ...           ...       ...          ...      ...        ...    ...
# 1111           AM  Amazonas         Tefé  1304203  2015-2019  total
# 1112           AM  Amazonas    Tonantins  1304237  2015-2019  total
# 1113           AM  Amazonas       Uarini  1304260  2015-2019  total
# 1114           AM  Amazonas      Urucará  1304302  2015-2019  total
# 1115           AM  Amazonas  Urucurituba  1304401  2015-2019  total
#
#                disease  cases           inc
# 0           Falciparum   3448  1.060298e+14
# 1           Falciparum     23  1.055994e+14
# 2           Falciparum    342  1.664534e+14
# 3           Falciparum     80  3.181561e+14
# 4           Falciparum   1016  2.506662e+14
# ...                ...    ...           ...
# 1111  Vivax+Falciparum     13  4.192128e+14
# 1112  Vivax+Falciparum      2  2.129699e+14
# 1113  Vivax+Falciparum      0  0.000000e+00
# 1114  Vivax+Falciparum      0  0.000000e+00
# 1115  Vivax+Falciparum      0  0.000000e+00
#
# [1116 rows x 9 columns]

# %% [markdown]
# Buscando o município com maior número de casos:

# %%
filtros = (epidem_indic['disease'].isin(malaria)) & (epidem_indic['period'].isin(periodos_desejados)) & (epidem_indic['state'].isin(amazonas))
dados_filtrados = epidem_indic[filtros]

# Agrupa os dados por estado e soma os casos
soma_casos_por_cidade = dados_filtrados.groupby('municipality')['cases'].sum()

# Ordena os estados em ordem decrescente de casos
soma_casos_por_cidade = soma_casos_por_cidade.sort_values(ascending=False)

# Obtém o estado com o maior número de casos
cidade_maior_casos = soma_casos_por_cidade.index[0]

#############################

# Agrupa os dados por estado e período

soma_casos_por_cidade_periodo = dados_filtrados.groupby(['municipality', 'period'])['cases'].sum()

soma_casos_por_cidade_periodo = soma_casos_por_cidade_periodo.sort_values(ascending=False)

cidade_periodo_maior_casos = soma_casos_por_cidade_periodo.index[0]


# Exibe o estado com o maior índice de casos
print(soma_casos_por_cidade)
print(' ')
print("Cidade com maior índice de casos:", cidade_maior_casos)
# Out:
# municipality
# Manaus                      786128
# São Gabriel da Cachoeira    158140
# Barcelos                    122514
# Coari                       112852
# Careiro                     105518
#                              ...
# Tonantins                     1088
# Amaturá                        604
# Urucurituba                    229
# Barreirinha                    201
# Boa Vista do Ramos             172
# Name: cases, Length: 62, dtype: int64
#
# Cidade com maior índice de casos: Manaus

# %% [markdown]
# Buscando o município com maior número de casos por período:

# %%
# Filtra os dados para o período de 2004-2008
dados_2004_2008 = dados_filtrados[dados_filtrados['period'] == '2004-2008']

# Agrupa os dados por estado e soma os casos para o período
soma_casos_2004_2008 = dados_2004_2008.groupby('municipality')['cases'].sum()

# Ordena os estados em ordem decrescente de casos para o período
soma_casos_2004_2008 = soma_casos_2004_2008.sort_values(ascending=False)

# Obtém o estado com o maior número de casos para o período
cidade_maior_casos_2004_2008 = soma_casos_2004_2008.index[0]

###############

dados_2015_2019 = dados_filtrados[dados_filtrados['period'] == '2015-2019']

soma_casos_2015_2019 = dados_2015_2019.groupby('municipality')['cases'].sum()

soma_casos_2015_2019 = soma_casos_2015_2019.sort_values(ascending=False)

cidade_maior_casos_2015_2019 = soma_casos_2015_2019.index[0]

# %%
# Exibe as cidades com o maior índice de casos para cada período
print("Período de 2004-2008:")
print(soma_casos_2004_2008)
print("Cidade com maior índice de casos no período de 2004-2008:", cidade_maior_casos_2004_2008)

print(' ')

print("Período de 2015-2019:")
print(soma_casos_2015_2019)
print("Cidade com maior índice de casos no período de 2015-2019:", cidade_maior_casos_2015_2019)
# Out:
# Período de 2004-2008:
# municipality
# Manaus                660604
# Careiro               101770
# Manacapuru             81632
# Coari                  80324
# Tefé                   74280
#                        ...
# Amaturá                  422
# Envira                   217
# Urucurituba              182
# Barreirinha              114
# Boa Vista do Ramos        74
# Name: cases, Length: 62, dtype: int64
# Cidade com maior índice de casos no período de 2004-2008: Manaus
#
# Período de 2015-2019:
# municipality
# Manaus                       125524
# São Gabriel da Cachoeira     117994
# Barcelos                      67246
# Santa Isabel do Rio Negro     43372
# Lábrea                        36544
#                               ...
# Anamã                            99
# Boa Vista do Ramos               98
# Barreirinha                      87
# Urucurituba                      47
# Anori                            28
# Name: cases, Length: 62, dtype: int64
# Cidade com maior índice de casos no período de 2015-2019: Manaus

# %%
municipio_max = ['Manaus']

# Filtra as linhas com os valores desejados na coluna 'disease' no DataFrame amazonas_df
combined_df = combined_df[combined_df['municipality'].isin(municipio_max)]

# Exibe o DataFrame filtrado para o Amazonas
combined_df = combined_df.reset_index(drop=True)
combined_df
# Out:
#    state_abbrev     state municipality  geocode     period   zone  \
# 0            AM  Amazonas       Manaus  1302603  2004-2008  rural
# 1            AM  Amazonas       Manaus  1302603  2015-2019  rural
# 2            AM  Amazonas       Manaus  1302603  2004-2008  urban
# 3            AM  Amazonas       Manaus  1302603  2015-2019  urban
# 4            AM  Amazonas       Manaus  1302603  2004-2008  total
# 5            AM  Amazonas       Manaus  1302603  2015-2019  total
# 6            AM  Amazonas       Manaus  1302603  2004-2008  rural
# 7            AM  Amazonas       Manaus  1302603  2015-2019  rural
# 8            AM  Amazonas       Manaus  1302603  2004-2008  urban
# 9            AM  Amazonas       Manaus  1302603  2015-2019  urban
# 10           AM  Amazonas       Manaus  1302603  2004-2008  total
# 11           AM  Amazonas       Manaus  1302603  2015-2019  total
# 12           AM  Amazonas       Manaus  1302603  2004-2008  rural
# 13           AM  Amazonas       Manaus  1302603  2015-2019  rural
# 14           AM  Amazonas       Manaus  1302603  2004-2008  urban
# 15           AM  Amazonas       Manaus  1302603  2015-2019  urban
# 16           AM  Amazonas       Manaus  1302603  2004-2008  total
# 17           AM  Amazonas       Manaus  1302603  2015-2019  total
#
#              disease   cases           inc
# 0         Falciparum   22273  5.205305e+14
# 1         Falciparum      78  1.822897e+14
# 2         Falciparum   44105  5.250701e+14
# 3         Falciparum     398  4.738191e+14
# 4         Falciparum   66378  7.862251e+14
# 5         Falciparum     476  4.468930e+14
# 6              Vivax   78745  1.840308e+14
# 7              Vivax   25859  6.043370e+14
# 8              Vivax  183519  2.184794e+14
# 9              Vivax   36387  4.331873e+14
# 10             Vivax  262264  3.106429e+14
# 11             Vivax   62246  5.843971e+14
# 12  Vivax+Falciparum     433  1.011941e+14
# 13  Vivax+Falciparum       8  1.869638e+14
# 14  Vivax+Falciparum    1227  1.460744e+14
# 15  Vivax+Falciparum      32  3.809600e-01
# 16  Vivax+Falciparum    1660  1.966214e+14
# 17  Vivax+Falciparum      40  3.755403e-01

# %%
# Filtra os dados para o período de 2004-2008
dados_2004_2008 = dados_filtrados[dados_filtrados['period'] == '2004-2008']

# Agrupa os dados por estado e soma os casos para o período
soma_casos_2004_2008 = dados_2004_2008.groupby(['disease', 'municipality'])['cases'].sum()

# Ordena os estados em ordem decrescente de casos para o período
soma_casos_2004_2008 = soma_casos_2004_2008.sort_values(ascending=False)

# Obtém o estado com o maior número de casos para o período
especie_maior_casos_2004_2008 = soma_casos_2004_2008.index[0]

###############

dados_2015_2019 = dados_filtrados[dados_filtrados['period'] == '2015-2019']

soma_casos_2015_2019 = dados_2015_2019.groupby(['disease', 'municipality'])['cases'].sum()

soma_casos_2015_2019 = soma_casos_2015_2019.sort_values(ascending=False)

especie_maior_casos_2015_2019 = soma_casos_2015_2019.index[0]

# %%
# Exibe as cidades com o maior índice de casos para cada período
print("Período de 2004-2008:")
print(soma_casos_2004_2008)
print("Espécie com maior índice de casos no período de 2004-2008:", especie_maior_casos_2004_2008)

print(' ')

print("Período de 2015-2019:")
print(soma_casos_2015_2019)
print("Espécie com maior índice de casos no período de 2015-2019:", especie_maior_casos_2015_2019)
# Out:
# Período de 2004-2008:
# disease           municipality
# Vivax             Manaus                524528
# Falciparum        Manaus                132756
# Vivax             Careiro                76002
#                   Manacapuru             63046
#                   Coari                  57906
#                                          ...
# Vivax+Falciparum  Envira                     1
#                   Fonte Boa                  1
#                   Eirunepé                   0
#                   Boa Vista do Ramos         0
#                   Urucurituba                0
# Name: cases, Length: 186, dtype: int64
# Espécie com maior índice de casos no período de 2004-2008: ('Vivax', 'Manaus')
#
# Período de 2015-2019:
# disease           municipality
# Vivax             Manaus                      124492
#                   São Gabriel da Cachoeira    101304
#                   Barcelos                     55134
#                   Lábrea                       35134
#                   Coari                        32208
#                                                ...
# Vivax+Falciparum  Iranduba                         0
#                   Itacoatiara                      0
#                   Itapiranga                       0
#                   Manacapuru                       0
#                   Urucurituba                      0
# Name: cases, Length: 186, dtype: int64
# Espécie com maior índice de casos no período de 2015-2019: ('Vivax', 'Manaus')
